# %%
fout = open("orders_eth_depth50_test.txt", "w")

with open('orders_eth_depth50_test.pkl', 'rb') as f:
    orders = pickle.load(f)
    

print(len(orders), file=fout)

for i in range(len(orders)):
    for j in range(50):
        print(orders['ask_price_' + str(j)][i], orders['ask_volume_' + str(j)][i], end="  ", file=fout)
    print(file=fout)
    print(file=fout)
    for j in range(50):
        print(orders['bid_price_' + str(j)][i], orders['bid_volume_' + str(j)][i], end="  ", file=fout)
    print(file=fout)
    print(file=fout)
    print(file=fout)
    
fout.close()

# %%
fout = open("trades_eth_test.txt", "w")

with open('trades_eth_test.pkl', 'rb') as f:
    trades = pickle.load(f)
    

print(len(trades), file=fout)

for i in range(len(trades)):
    print(trades['first_trade_timestamp'][i], trades['trade_price'][i],
          trades['trade_size'][i], trades['is_buyer_maker'][i],
          file=fout)
    
fout.close()

# %%
# Out:
#            timestamp  ask_price_0  ask_price_1  ask_price_2  ask_price_3  \
# 0      1603659600000       407.53       407.54       407.55       407.56
# 1      1603659600100       407.53       407.54       407.55       407.56
# 2      1603659600200       407.53       407.54       407.55       407.56
# 3      1603659600300       407.53       407.54       407.55       407.56
# 4      1603659600400       407.53       407.54       407.55       407.56
# ...              ...          ...          ...          ...          ...
# 35996  1603663199600       408.01       408.02       408.03       408.04
# 35997  1603663199700       408.01       408.02       408.03       408.04
# 35998  1603663199800       408.01       408.02       408.03       408.04
# 35999  1603663199900       408.01       408.02       408.03       408.04
# 36000  1603663200000       408.01       408.02       408.03       408.04
#
#        ask_price_4  ask_price_5  ask_price_6  ask_price_7  ask_price_8  ...  \
# ...
